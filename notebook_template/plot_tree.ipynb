# %%
import sys
import matplotlib.pylab as plt
from Bio import Phylo

# %%
# !ls '../workflow/Ca/request_sequence/'
# Out:
# all_sequence.aln  all_sequence.dnd

# %%
test_in_filename = '../workflow/Na/request_sequence/all_sequence.dnd'
test_out = 'sample.png'

in_filename = test_in_filename
out_filename = test_out

# %%
in_filename, out_filename
# Out:
# ('../workflow/Na/request_sequence/all_sequence.dnd', 'sample.png')

# %%
with open(in_filename) as file:
    print(file.read())
# Out:
# (
# (
# (
# NP_001342095.1[Mus_musculus]:0.00700,
# XP_008760136.1[Rattus_norvegicus]:0.00661)
# :0.00710,
# (
# (
# (
# (
# (
# (
# (
# (
# XP_003465977.1[Cavia_porcellus]:0.03204,
# (
# (
# XP_020922427.1[Sus_scrofa]:0.02842,
# XP_853396.1[Canis_lupus_familiaris]:0.02677)
# :0.00260,
# NP_000325.4[Homo_sapiens]:0.02873)
# :0.00339)
# :0.00189,
# XP_002719526.1[Oryctolagus_cuniculus]:0.03309)
# :0.00401,
# (
# XP_006532050.1[Mus_musculus]:0.01490,
# NP_037310.1[Rattus_norvegicus]:0.01445)
# :0.02216)
# :0.09702,
# (
# (
# (
# (
# (
# NP_001240789.1[Mus_musculus]:0.00696,
# NP_037257.1[Rattus_norvegicus]:0.00740)
# :0.01789,
# XP_005001164.1[Cavia_porcellus]:0.02902)
# :0.00259,
# NP_000326.2[Homo_sapiens]:0.03016)
# :0.00113,
# (
# XP_005634204.1[Canis_lupus_familiaris]:0.02226,
# XP_020927335.1[Sus_scrofa]:0.02593)
# :0.00301)
# :0.01939,
# XP_017195623.1[Oryctolagus_cuniculus]:0.05329)
# :0.16139)
# :0.02815,
# (
# (
# NP_113874.1[Rattus_norvegicus]:0.06418,
# ...

# %%
tree = Phylo.read(in_filename, "newick")
Phylo.draw(tree, do_show=False)
plt.savefig(out_filename)

# %%
new_tree = Phylo.read(in_filename, "newick")
Phylo.draw(new_tree)
